# %%
import pandas as pd

data = pd.read_csv('Data/datos_trabajados_2014_2017.csv', sep=';')

# %%
data.head()
# Out:
#    credito_numero_sucursal credito_cantidad_total_cuotas  \
# 0                      136                        1 a 12
# 1                      119                        1 a 12
# 2                      146                        1 a 12
# 3                      119                        1 a 12
# 4                      118                        1 a 12
#
#    credito_importe_cuota credito_ultima_cuota_paga  credito_monto  \
# 0                 1162.1                    1 a 12        10458.9
# 1                  498.1                    1 a 12         4482.9
# 2                  989.7                   25 a 36         2969.1
# 3                  152.3                    1 a 12         1827.6
# 4                  686.5                    1 a 12         8238.0
#
#    credito_capital credito_estado credito_tipo_credito  credito_tna  \
# 0          7125.50      Cancelado             Efectivo        81.15
# 1          3053.79      Cancelado             Efectivo        81.17
# ...

# %%
data.columns
# Out:
# Index(['credito_numero_sucursal', 'credito_cantidad_total_cuotas',
#        'credito_importe_cuota', 'credito_ultima_cuota_paga', 'credito_monto',
#        'credito_capital', 'credito_estado', 'credito_tipo_credito',
#        'credito_tna', 'credito_tem', 'credito_importe_interes',
#        'credito_fecha_alta', 'cliente_cantidad_creditos', 'cliente_sexo',
#        'cliente_sucursal_asociada', 'cliente_ingresos',
#        'cliente_codigo_provincia', 'cliente_codigo_nacionalidad',
#        'cliente_codigo_estado_civil', 'cliente_edad'],
#       dtype='object')

# %%
data.credito_estado.value_counts()
# Out:
# Cancelado     859666
# En legales    122607
# Incobrable     41098
# Anulado        19931
# Pendiente       5273
# Name: credito_estado, dtype: int64

# %%
data.shape
# Out:
# (1048575, 20)

# %% [markdown]
# # Estados del crédito.
# * "En legales" e "Incobrable" sería "No pagado".
# * "Anulado" o "Cancelado" sería "Pagado".
# * "Pendiente" es el que tenemos que predecir.

# %% [markdown]
# # Datos sin trabajar.

# %%
data_cruda = pd.read_csv('Data/datos_no_trabajados_2017.csv', sep=';')
data_cruda.head()
# Out:
# C:\Users\Manu\anaconda3\envs\dhdsblend\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (20) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    tcre_numero_sucursal tcre_fecha_vencimiento tcre_nueva_fecha_vencimiento  \
# 0                    40              2/11/2017                          NaN
# 1                    79              2/11/2017                          NaN
# 2                    31              2/11/2017                          NaN
# 3                   154              2/11/2017                          NaN
# 4                    27               2/2/2018                     2/2/2018
#
#    tcre_cantidad_total_cuotas  tcre_importe_cuota  tcre_ultima_cuota_paga  \
# 0                          15               405.4                       3
# 1                           3              1120.5                       3
# ...

# %%
data_cruda.shape
# Out:
# (425590, 35)
